# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os

# %%
os.chdir('C:/Users/Moiz_Ali_Abedin/Desktop/FTI///Python Basic Module 1/Files of PANDAS')

# %%
ds=pd.read_csv('TelecomChurn.csv')
ds
# Out:
#      state  account length  area code phone number international plan  \
# 0       KS             128        415     382-4657                 no
# 1       OH             107        415     371-7191                 no
# 2       NJ             137        415     358-1921                 no
# 3       OH              84        408     375-9999                yes
# 4       OK              75        415     330-6626                yes
# 5       AL             118        510     391-8027                yes
# 6       MA             121        510     355-9993                 no
# 7       MO             147        415     329-9001                yes
# 8       LA             117        408     335-4719                 no
# 9       WV             141        415     330-8173                yes
# 10      IN              65        415     329-6603                 no
# 11      RI              74        415     344-9403                 no
# ...

# %%
ds.shape
# Out:
# (3333, 21)

# %%
ds.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...    total eve calls  total eve charge  \
# ...

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 21 columns):
# state                     3333 non-null object
# account length            3333 non-null int64
# area code                 3333 non-null int64
# phone number              3333 non-null object
# international plan        3333 non-null object
# voice mail plan           3333 non-null object
# number vmail messages     3333 non-null int64
# total day minutes         3333 non-null float64
# total day calls           3333 non-null int64
# total day charge          3333 non-null float64
# total eve minutes         3333 non-null float64
# total eve calls           3333 non-null int64
# total eve charge          3333 non-null float64
# total night minutes       3333 non-null float64
# total night calls         3333 non-null int64
# total night charge        3333 non-null float64
# total intl minutes        3333 non-null float64
# total intl calls          3333 non-null int64
# ...

# %%
ds.describe()
# Out:
#        account length    area code  number vmail messages  total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        total day calls  total day charge  total eve minutes  total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
ds.describe(include=['object','bool'])
# Out:
#        state phone number international plan voice mail plan  churn
# count   3333         3333               3333            3333   3333
# unique    51         3333                  2               2      2
# top       WV     356-9187                 no              no  False
# freq     106            1               3010            2411   2850

# %%
ds['churn'].value_counts()
# Out:
# False    2850
# True      483
# Name: churn, dtype: int64

# %%
ds['churn'].value_counts(normalize=True)
# Out:
# False    0.855086
# True     0.144914
# Name: churn, dtype: float64

# %%
ds['state'].value_counts()
# Out:
# WV    106
# MN     84
# NY     83
# AL     80
# WI     78
# OH     78
# OR     78
# VA     77
# WY     77
# CT     74
# ID     73
# MI     73
# VT     73
# TX     72
# UT     72
# IN     71
# KS     70
# MD     70
# MT     68
# NJ     68
# NC     68
# WA     66
# CO     66
# NV     66
# MA     65
# MS     65
# RI     65
# AZ     64
# FL     63
# MO     63
# ND     62
# ME     62
# NM     62
# OK     61
# DE     61
# NE     61
# SC     60
# SD     60
# KY     59
# IL     58
# NH     56
# AR     55
# DC     54
# GA     54
# TN     53
# HI     53
# AK     52
# LA     51
# PA     45
# IA     44
# CA     34
# Name: state, dtype: int64

# %%
ds['churn'].value_counts().plot(kind='bar', figsize=(4,5))

# %%
ds['state'].value_counts().plot(kind='pie',figsize=(20,10))

# %%
ds['total day calls'].describe()
# Out:
# count    3333.000000
# mean      100.435644
# std        20.069084
# min         0.000000
# 25%        87.000000
# 50%       101.000000
# 75%       114.000000
# max       165.000000
# Name: total day calls, dtype: float64

# %%
sns.boxplot(x='total day calls',data=ds)

# %%
ds.describe(include=['float'])
# Out:
#        total day minutes  total day charge  total eve minutes  \
# count        3333.000000       3333.000000        3333.000000
# mean          179.775098         30.562307         200.980348
# std            54.467389          9.259435          50.713844
# min             0.000000          0.000000           0.000000
# 25%           143.700000         24.430000         166.600000
# 50%           179.400000         30.500000         201.400000
# 75%           216.400000         36.790000         235.300000
# max           350.800000         59.640000         363.700000
#
#        total eve charge  total night minutes  total night charge  \
# count       3333.000000          3333.000000         3333.000000
# mean          17.083540           200.872037            9.039325
# std            4.310668            50.573847            2.275873
# min            0.000000            23.200000            1.040000
# 25%           14.160000           167.000000            7.520000
# ...

# %%
ds['total day charge'].describe()
# Out:
# count    3333.000000
# mean       30.562307
# std         9.259435
# min         0.000000
# 25%        24.430000
# 50%        30.500000
# 75%        36.790000
# max        59.640000
# Name: total day charge, dtype: float64

# %%
sns.distplot(ds['total day charge'],bins=10,kde=False)
